# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
products = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Project/Dataset_new/products.json')
customers = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Project/Dataset_new/customers.json')
ratings = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Project/Dataset_new/ratings.json')

# %%
products.head()
# Out:
#    Id                                            Name  UnitPrice
# 0   1                         Build your own computer     1200.0
# 1   2  Digital Storm VANQUISH 3 Custom Performance PC     1259.0
# 2   3             Lenovo IdeaCentre 600 All-in-One PC      500.0
# 3   4                       Apple MacBook Pro 13-inch     1800.0
# 4   5                       Asus N551JK-XO076H Laptop     1500.0

# %%
customers.head()
# Out:
#        Id     NickName
# 0  103603  1000kgthanh
# 1  103760  999999999ok
# 2  103829       ac7ive
# 3       1        admin
# 4  103839  ahkk.nguyen

# %%
ratings.head()
# Out:
#    CustomerID  ProductID  Rate           CreateDate
# 0      103416        619     1  2018/01/01 01:36:30
# 1      103654        411     1  2018/01/01 01:36:35
# 2      103954        298     3  2018/01/01 01:36:38
# 3      103672        361     5  2018/01/01 01:37:15
# 4      103960        536     5  2018/01/01 02:36:25

# %%
print(products.shape)
print(ratings.shape)
print(customers.shape)
# Out:
# (691, 3)
# (130754, 4)
# (678, 2)

# %%
#missing row info
products.isnull().sum()
# Out:
# Id           0
# Name         0
# UnitPrice    0
# dtype: int64

# %%
customers.isnull().sum()
# Out:
# Id          0
# NickName    0
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# CustomerID    0
# ProductID     0
# Rate          0
# CreateDate    0
# dtype: int64

# %%
print(products.duplicated().sum())
print(ratings.duplicated().sum())
print(customers.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
products.rename(columns = {'Id':'ProductID'}, inplace = True)

# %% [markdown]
# # Popularity Based System

# %% [markdown]
# ## minimum 250 rating then recommned with highest avg rating

# %%
ratings_with_name = ratings.merge(products, on='ProductID')

# %%
ratings_with_name
# Out:
#         CustomerID  ProductID  Rate           CreateDate  \
# 0           103416        619     1  2018/01/01 01:36:30
# 1           103401        619     4  2018/01/05 14:36:40
# 2           103491        619     1  2018/01/15 19:36:29
# 3           103856        619     4  2018/01/16 07:37:25
# 4           103320        619     4  2018/01/29 09:36:28
# ...            ...        ...   ...                  ...
# 130749      103890        236     4  2022/03/01 12:58:19
# 130750      103587        236     4  2022/03/05 14:56:46
# 130751      103970        236     3  2022/03/06 17:46:03
# 130752      103541        236     3  2022/03/07 15:58:41
# 130753      103394        236     3  2022/03/10 17:03:49
#
#                                                      Name  UnitPrice
# 0       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 1       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 2       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 3       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 4       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# ...                                                   ...        ...
# 130749  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130750  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130751  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130752  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130753  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
#
# [130754 rows x 6 columns]

# %%
ratings_with_name.groupby('Name').count()['Rate']
# Out:
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adjustable    186
# $100 Physical Gift Card                                  191
# $25 Virtual Gift Card                                    183
# $50 Physical Gift Card                                   196
# 1/10 Carat t.w. Diamond Promise Ring                     187
#                                                         ...
# Ống hút gạo OCHAO 500 Gram                               183
# Ống hút inox                                             388
# Ống hút kim loại                                         203
# Ống hút tre                                              204
# 레드슈즈                                                     190
# Name: Rate, Length: 625, dtype: int64

# %%
num_rating_df = ratings_with_name.groupby('Name').count()['Rate'].reset_index()
num_rating_df.rename(columns={'Rate': 'nums-ratings'}, inplace=True)
num_rating_df
# Out:
#                                                   Name  nums-ratings
# 0    "Love" Necklace 14K Yellow Gold 16" to 18" Adj...           186
# 1                              $100 Physical Gift Card           191
# 2                                $25 Virtual Gift Card           183
# 3                               $50 Physical Gift Card           196
# 4                 1/10 Carat t.w. Diamond Promise Ring           187
# ..                                                 ...           ...
# 620                         Ống hút gạo OCHAO 500 Gram           183
# 621                                       Ống hút inox           388
# 622                                   Ống hút kim loại           203
# 623                                        Ống hút tre           204
# 624                                               레드슈즈           190
#
# [625 rows x 2 columns]

# %%
# printing the avg rating
avg_rating_df = ratings_with_name.groupby('Name').mean()['Rate'].reset_index()
avg_rating_df.rename(columns={'Rate': 'avg-ratings'}, inplace=True)
avg_rating_df
# Out:
# <ipython-input-17-63a69c289792>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = ratings_with_name.groupby('Name').mean()['Rate'].reset_index()
#                                                   Name  avg-ratings
# 0    "Love" Necklace 14K Yellow Gold 16" to 18" Adj...     3.059140
# 1                              $100 Physical Gift Card     3.115183
# 2                                $25 Virtual Gift Card     3.229508
# 3                               $50 Physical Gift Card     3.275510
# 4                 1/10 Carat t.w. Diamond Promise Ring     3.262032
# ..                                                 ...          ...
# 620                         Ống hút gạo OCHAO 500 Gram     3.087432
# 621                                       Ống hút inox     3.154639
# 622                                   Ống hút kim loại     3.261084
# 623                                        Ống hút tre     3.225490
# 624                                               레드슈즈     3.242105
#
# [625 rows x 2 columns]

# %%
#merging two dataframe
popular_df = num_rating_df.merge(avg_rating_df, on='Name')
popular_df
# Out:
#                                                   Name  nums-ratings  \
# 0    "Love" Necklace 14K Yellow Gold 16" to 18" Adj...           186
# 1                              $100 Physical Gift Card           191
# 2                                $25 Virtual Gift Card           183
# 3                               $50 Physical Gift Card           196
# 4                 1/10 Carat t.w. Diamond Promise Ring           187
# ..                                                 ...           ...
# 620                         Ống hút gạo OCHAO 500 Gram           183
# 621                                       Ống hút inox           388
# 622                                   Ống hút kim loại           203
# 623                                        Ống hút tre           204
# 624                                               레드슈즈           190
#
#      avg-ratings
# 0       3.059140
# 1       3.115183
# 2       3.229508
# 3       3.275510
# 4       3.262032
# ..           ...
# 620     3.087432
# 621     3.154639
# 622     3.261084
# 623     3.225490
# 624     3.242105
#
# [625 rows x 3 columns]

# %%
#logic
#products having rating >= 50 in total
#top 50 products, sort based on avg rating

popular_df = popular_df[popular_df['nums-ratings'] >= 50].sort_values('avg-ratings', ascending=False).head(50)
popular_df
# Out:
#                                                   Name  nums-ratings  \
# 443  Men's Diamond Mariner Necklace 4 ct tw Round-c...           180
# 9    3-Stone Promise Ring 1/6 ct tw Diamonds Sterli...           174
# 221  Disney Treasures The Aristocats Diamond Earrin...           189
# 107  Cross Necklace 1/10 ct tw Diamonds Sterling Si...           194
# 504                                  Quần Jeans Nữ B&Y           202
# 453                   Móc khóa BTS phát sáng BTS mẫu B           192
# 343                       Key Necklace 14K Yellow Gold           179
# 61   Blue Topaz Ring 1/15 ct tw Diamonds 10K White ...           186
# 49   Black Diamond Necklace 1/15 carat tw 10K Rose ...           187
# 506                         Ray Ban Aviator Sunglasses           213
# 404  Le Vian Diamond Ring 7/8 ct tw Round-cut 14K H...           173
# 497  Promise Ring 1/5 ct tw Diamonds Sterling Silve...           173
# 248  Ethiopian Opal & Diamond Ring 1/10 ct tw 10K R...           193
# 466                                          Nhóm test           178
# 164  Diamond Promise Ring 1/10 ct tw Baguette & Rou...           203
# 152  Diamond Hoop Earrings 1 ct tw Round-Cut Sterli...           183
# 405  Le Vian Emerald Earrings 1/4 ct tw Diamonds 14...           184
# 13                                 Adobe Photoshop CS4           188
# 494                                Pride and Prejudice           171
# 114  Cultured Pearl Necklace Sapphires/Diamonds 10K...           169
# 67                             Build your own computer           207
# 208  Diamond Teardrop Ring 1/15 ct tw Round-cut 10K...           184
# 286  Giày Sneaker Unisex Converse Chuck Taylor All ...           186
# 619                                Ống hút giấy - copy           166
# 28                           Apple MacBook Pro 13-inch           184
# 350  Lab-Created Emerald Ring Diamond Accents 10K Y...           178
# 430  Leo Zodiac Ring 1/10 ct tw Diamonds Sterling S...           169
# 317       Heart Necklace Diamond Accents 10K Rose Gold           189
# 283            Geometric Hoop Earrings 14K Yellow Gold           168
# 101                                      Combo Hoa ban           211
# 396  Le Vian Diamond Butterfly Necklace 3/4 ct tw 1...           184
# 148  Diamond Heart Ring 1/15 ct tw Round-cut Sterli...           178
# 220  Disney Treasures Mickey Mouse Lab-Created Opal...           197
# 127             Diamond Cross Necklace 10K Yellow Gold           182
# 233  Disney Treasures Winnie the Pooh Mother of Pea...           173
# 117                                     Custom T-Shirt           195
# 150      Diamond Heart Ring 1/20 ct tw Sterling Silver           189
# 336                          Hành Trình Về Phương Đông           178
# 524         Silver Color Stone Family Dog Tag Necklace           188
# 125  Diamond Cross Necklace 1/15 ct tw Round-cut 10...           170
# 537  Stamped Textured Heart Hoop Earrings 14K Yello...           199
# 328                      Hoop Earrings 14K Yellow Gold           395
# 448                  Miracle: Letters to the President           190
# 180  Diamond Promise Ring 1/5 ct tw Round/Baguette ...           190
# 118             Cốc xếp lúa mạch thân thiện môi trường           203
# 567                                            Túi cói           203
# 460  Neil Lane Diamond Wedding Band 1/4 ct tw 14K W...           181
# 185  Diamond Promise Ring 1/6 ct tw Round-cut 10K T...           194
# 282        Garnet Ring Diamond Accents 10K Yellow Gold           185
# 32                           Asus N551JK-XO076H Laptop           198
#
#      avg-ratings
# 443     3.438889
# 9       3.413793
# 221     3.412698
# 107     3.407216
# 504     3.386139
# 453     3.385417
# 343     3.374302
# 61      3.370968
# 49      3.368984
# 506     3.361502
# 404     3.358382
# 497     3.358382
# 248     3.357513
# 466     3.353933
# 164     3.349754
# 152     3.349727
# 405     3.347826
# 13      3.345745
# 494     3.345029
# 114     3.343195
# 67      3.342995
# 208     3.342391
# 286     3.338710
# 619     3.337349
# 28      3.336957
# 350     3.331461
# 430     3.331361
# 317     3.328042
# 283     3.327381
# 101     3.327014
# 396     3.326087
# 148     3.325843
# 220     3.324873
# 127     3.324176
# 233     3.323699
# 117     3.323077
# 150     3.322751
# 336     3.320225
# 524     3.319149
# 125     3.317647
# 537     3.316583
# 328     3.316456
# 448     3.315789
# 180     3.315789
# 118     3.315271
# 567     3.315271
# 460     3.314917
# 185     3.314433
# 282     3.313514
# 32      3.313131

# %%
popular_df = popular_df.merge(products, on='Name').drop_duplicates('Name')[['Name','nums-ratings', 'avg-ratings']]
popular_df
# Out:
#                                                  Name  nums-ratings  \
# 0   Men's Diamond Mariner Necklace 4 ct tw Round-c...           180
# 1   3-Stone Promise Ring 1/6 ct tw Diamonds Sterli...           174
# 2   Disney Treasures The Aristocats Diamond Earrin...           189
# 3   Cross Necklace 1/10 ct tw Diamonds Sterling Si...           194
# 4                                   Quần Jeans Nữ B&Y           202
# 5                    Móc khóa BTS phát sáng BTS mẫu B           192
# 6                        Key Necklace 14K Yellow Gold           179
# 7   Blue Topaz Ring 1/15 ct tw Diamonds 10K White ...           186
# 8   Black Diamond Necklace 1/15 carat tw 10K Rose ...           187
# 9                          Ray Ban Aviator Sunglasses           213
# 10  Le Vian Diamond Ring 7/8 ct tw Round-cut 14K H...           173
# 11  Promise Ring 1/5 ct tw Diamonds Sterling Silve...           173
# 12  Ethiopian Opal & Diamond Ring 1/10 ct tw 10K R...           193
# 13                                          Nhóm test           178
# 14  Diamond Promise Ring 1/10 ct tw Baguette & Rou...           203
# 15  Diamond Hoop Earrings 1 ct tw Round-Cut Sterli...           183
# 16  Le Vian Emerald Earrings 1/4 ct tw Diamonds 14...           184
# 17                                Adobe Photoshop CS4           188
# 18                                Pride and Prejudice           171
# 19  Cultured Pearl Necklace Sapphires/Diamonds 10K...           169
# 20                            Build your own computer           207
# 21  Diamond Teardrop Ring 1/15 ct tw Round-cut 10K...           184
# 22  Giày Sneaker Unisex Converse Chuck Taylor All ...           186
# 23                                Ống hút giấy - copy           166
# 24                          Apple MacBook Pro 13-inch           184
# 25  Lab-Created Emerald Ring Diamond Accents 10K Y...           178
# 26  Leo Zodiac Ring 1/10 ct tw Diamonds Sterling S...           169
# 27       Heart Necklace Diamond Accents 10K Rose Gold           189
# 28            Geometric Hoop Earrings 14K Yellow Gold           168
# 29                                      Combo Hoa ban           211
# 30  Le Vian Diamond Butterfly Necklace 3/4 ct tw 1...           184
# 31  Diamond Heart Ring 1/15 ct tw Round-cut Sterli...           178
# 32  Disney Treasures Mickey Mouse Lab-Created Opal...           197
# 33             Diamond Cross Necklace 10K Yellow Gold           182
# 34  Disney Treasures Winnie the Pooh Mother of Pea...           173
# 35                                     Custom T-Shirt           195
# 36      Diamond Heart Ring 1/20 ct tw Sterling Silver           189
# 37                          Hành Trình Về Phương Đông           178
# 38         Silver Color Stone Family Dog Tag Necklace           188
# 39  Diamond Cross Necklace 1/15 ct tw Round-cut 10...           170
# 40  Stamped Textured Heart Hoop Earrings 14K Yello...           199
# 41                      Hoop Earrings 14K Yellow Gold           395
# 43                  Miracle: Letters to the President           190
# 44  Diamond Promise Ring 1/5 ct tw Round/Baguette ...           190
# 45             Cốc xếp lúa mạch thân thiện môi trường           203
# 46                                            Túi cói           203
# 47  Neil Lane Diamond Wedding Band 1/4 ct tw 14K W...           181
# 48  Diamond Promise Ring 1/6 ct tw Round-cut 10K T...           194
# 49        Garnet Ring Diamond Accents 10K Yellow Gold           185
# 50                          Asus N551JK-XO076H Laptop           198
#
#     avg-ratings
# 0      3.438889
# 1      3.413793
# 2      3.412698
# 3      3.407216
# 4      3.386139
# 5      3.385417
# 6      3.374302
# 7      3.370968
# 8      3.368984
# 9      3.361502
# 10     3.358382
# 11     3.358382
# 12     3.357513
# 13     3.353933
# 14     3.349754
# 15     3.349727
# 16     3.347826
# 17     3.345745
# 18     3.345029
# 19     3.343195
# 20     3.342995
# 21     3.342391
# 22     3.338710
# 23     3.337349
# 24     3.336957
# 25     3.331461
# 26     3.331361
# 27     3.328042
# 28     3.327381
# 29     3.327014
# 30     3.326087
# 31     3.325843
# 32     3.324873
# 33     3.324176
# 34     3.323699
# 35     3.323077
# 36     3.322751
# 37     3.320225
# 38     3.319149
# 39     3.317647
# 40     3.316583
# 41     3.316456
# 43     3.315789
# 44     3.315789
# 45     3.315271
# 46     3.315271
# 47     3.314917
# 48     3.314433
# 49     3.313514
# 50     3.313131

# %%
#DONE

# %% [markdown]
# # Collabrative Filtering Rating Based Product Recommnedation
# ##

# %%
customers.rename(columns = {'Id':'CustomerID'}, inplace = True)

# %%
ratings_with_name.groupby('CustomerID').count()['Rate']
# Out:
# CustomerID
# 3          159
# 6          538
# 13874      561
# 13879      389
# 13885      103
#           ...
# 103988     387
# 103991     247
# 103992     140
# 103996    1427
# 103997     289
# Name: Rate, Length: 344, dtype: int64

# %%
notRated = ratings_with_name.groupby('CustomerID').count()['Rate'] > 200
rated_user = notRated[notRated].index
rated_user
# Out:
# Int64Index([     6,  13874,  13879,  14180,  14902,  14906,  15018,  15042,
#              15202,  22881,
#             ...
#             103971, 103972, 103977, 103982, 103985, 103987, 103988, 103991,
#             103996, 103997],
#            dtype='int64', name='CustomerID', length=250)

# %%
rated_user.size
# Out:
# 250

# %%
ratings_with_name
# Out:
#         CustomerID  ProductID  Rate           CreateDate  \
# 0           103416        619     1  2018/01/01 01:36:30
# 1           103401        619     4  2018/01/05 14:36:40
# 2           103491        619     1  2018/01/15 19:36:29
# 3           103856        619     4  2018/01/16 07:37:25
# 4           103320        619     4  2018/01/29 09:36:28
# ...            ...        ...   ...                  ...
# 130749      103890        236     4  2022/03/01 12:58:19
# 130750      103587        236     4  2022/03/05 14:56:46
# 130751      103970        236     3  2022/03/06 17:46:03
# 130752      103541        236     3  2022/03/07 15:58:41
# 130753      103394        236     3  2022/03/10 17:03:49
#
#                                                      Name  UnitPrice
# 0       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 1       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 2       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 3       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 4       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# ...                                                   ...        ...
# 130749  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130750  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130751  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130752  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130753  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
#
# [130754 rows x 6 columns]

# %%
filter_rating = ratings_with_name[ratings_with_name['CustomerID'].isin(rated_user)]
filter_rating[ratings_with_name['CustomerID'].isin(rated_user)]
filter_rating
# Out:
# <ipython-input-27-9d32bfd70049>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filter_rating[ratings_with_name['CustomerID'].isin(rated_user)]
#         CustomerID  ProductID  Rate           CreateDate  \
# 0           103416        619     1  2018/01/01 01:36:30
# 1           103401        619     4  2018/01/05 14:36:40
# 2           103491        619     1  2018/01/15 19:36:29
# 4           103320        619     4  2018/01/29 09:36:28
# 5            22881        619     4  2018/02/10 21:37:56
# ...            ...        ...   ...                  ...
# 130749      103890        236     4  2022/03/01 12:58:19
# 130750      103587        236     4  2022/03/05 14:56:46
# 130751      103970        236     3  2022/03/06 17:46:03
# 130752      103541        236     3  2022/03/07 15:58:41
# 130753      103394        236     3  2022/03/10 17:03:49
#
#                                                      Name  UnitPrice
# 0       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 1       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 2       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 4       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 5       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# ...                                                   ...        ...
# 130749  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130750  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130751  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130752  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130753  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
#
# [117150 rows x 6 columns]

# %%
y = filter_rating.groupby('Name').count()['Rate']>= 50
famous_products= y[y].index
famous_products
# Out:
# Index(['"Love" Necklace 14K Yellow Gold 16" to 18" Adjustable',
#        '$100 Physical Gift Card', '$25 Virtual Gift Card',
#        '$50 Physical Gift Card', '1/10 Carat t.w. Diamond Promise Ring',
#        '1/20 Carat t.w. Black and white Diamond Promise Ring',
#        '1/6 Ct. tw Diamond Initials Couple's Heart Necklace',
#        '1/8 Ct. tw Diamond Nameplate Heart Necklace',
#        '16" Adjustable Rope Chain 14K Yellow Gold Appx. 1.2mm',
#        '3-Stone Promise Ring 1/6 ct tw Diamonds Sterling Silver',
#        ...
#        'Đầm Suông B&Y', 'Ống Hút Kim Loại Bằng Thép Không Gỉ',
#        'Ống hút cỏ bàng khô - Hộp 500 ống', 'Ống hút giấy',
#        'Ống hút giấy - copy', 'Ống hút gạo OCHAO 500 Gram', 'Ống hút inox',
#        'Ống hút kim loại', 'Ống hút tre', '레드슈즈'],
#       dtype='object', name='Name', length=625)

# %%
famous_products.size
# Out:
# 625

# %%
final_ratings = filter_rating[filter_rating['Name'].isin(famous_products)]
# final_ratings.drop_duplicates()
final_ratings
# Out:
#         CustomerID  ProductID  Rate           CreateDate  \
# 0           103416        619     1  2018/01/01 01:36:30
# 1           103401        619     4  2018/01/05 14:36:40
# 2           103491        619     1  2018/01/15 19:36:29
# 4           103320        619     4  2018/01/29 09:36:28
# 5            22881        619     4  2018/02/10 21:37:56
# ...            ...        ...   ...                  ...
# 130749      103890        236     4  2022/03/01 12:58:19
# 130750      103587        236     4  2022/03/05 14:56:46
# 130751      103970        236     3  2022/03/06 17:46:03
# 130752      103541        236     3  2022/03/07 15:58:41
# 130753      103394        236     3  2022/03/10 17:03:49
#
#                                                      Name  UnitPrice
# 0       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 1       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 2       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 4       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# 5       Le Vian Chocolate Diamonds 1/4 ct tw Earrings ...     1049.0
# ...                                                   ...        ...
# 130749  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130750  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130751  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130752  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
# 130753  Black & White Diamond Promise Ring 1/6 ct tw S...      219.0
#
# [117150 rows x 6 columns]

# %%
pt = final_ratings.pivot_table(index='Name', columns='CustomerID', values='Rate')
pt
# Out:
# CustomerID                                          6       13874   13879   \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     1.0     5.0     2.0
# $100 Physical Gift Card                                1.0     4.0     NaN
# $25 Virtual Gift Card                                  NaN     4.5     NaN
# $50 Physical Gift Card                                 1.0     5.0     NaN
# 1/10 Carat t.w. Diamond Promise Ring                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             1.0     NaN     2.0
# Ống hút inox                                           1.0     4.0     NaN
# Ống hút kim loại                                       NaN     5.0     5.0
# Ống hút tre                                            NaN     NaN     NaN
# 레드슈즈                                                   1.0     5.0     NaN
#
# CustomerID                                          14180   14902   14906   \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     NaN     1.0     NaN
# $100 Physical Gift Card                                NaN     1.0     4.0
# $25 Virtual Gift Card                                  NaN     NaN     4.0
# $50 Physical Gift Card                                 NaN     NaN     NaN
# 1/10 Carat t.w. Diamond Promise Ring                   NaN     1.0     NaN
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             4.0     NaN     NaN
# Ống hút inox                                           4.0     1.0     4.0
# Ống hút kim loại                                       NaN     1.0     NaN
# Ống hút tre                                            4.0     NaN     NaN
# 레드슈즈                                                   NaN     NaN     NaN
#
# CustomerID                                          15018   15042   15202   \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     NaN     2.0     NaN
# $100 Physical Gift Card                                4.0     NaN     NaN
# $25 Virtual Gift Card                                  NaN     NaN     NaN
# $50 Physical Gift Card                                 4.0     NaN     NaN
# 1/10 Carat t.w. Diamond Promise Ring                   4.0     NaN     NaN
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             4.0     5.0     NaN
# Ống hút inox                                           NaN     3.0     1.0
# Ống hút kim loại                                       NaN     3.5     1.0
# Ống hút tre                                            4.0     NaN     NaN
# 레드슈즈                                                   NaN     3.5     1.0
#
# CustomerID                                            22881   ...  103971  \
# Name                                                          ...
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...       NaN  ...     NaN
# $100 Physical Gift Card                             5.000000  ...     5.0
# $25 Virtual Gift Card                               3.000000  ...     5.0
# $50 Physical Gift Card                              3.333333  ...     NaN
# 1/10 Carat t.w. Diamond Promise Ring                4.000000  ...     5.0
# ...                                                      ...  ...     ...
# Ống hút gạo OCHAO 500 Gram                          4.000000  ...     5.0
# Ống hút inox                                        3.200000  ...     NaN
# Ống hút kim loại                                    2.333333  ...     5.0
# Ống hút tre                                         4.000000  ...     5.0
# 레드슈즈                                                5.000000  ...     5.0
#
# CustomerID                                          103972  103977    103982  \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     5.0     NaN       NaN
# $100 Physical Gift Card                                5.0     NaN  5.000000
# $25 Virtual Gift Card                                  NaN     NaN  5.000000
# $50 Physical Gift Card                                 5.0     NaN       NaN
# 1/10 Carat t.w. Diamond Promise Ring                   5.0     NaN  5.000000
# ...                                                    ...     ...       ...
# Ống hút gạo OCHAO 500 Gram                             NaN     NaN  4.000000
# Ống hút inox                                           3.0     NaN  4.666667
# Ống hút kim loại                                       1.0     5.0  5.000000
# Ống hút tre                                            NaN     NaN       NaN
# 레드슈즈                                                   NaN     5.0  5.000000
#
# CustomerID                                          103985  103987  103988  \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     NaN     NaN     5.0
# $100 Physical Gift Card                                NaN     NaN     5.0
# $25 Virtual Gift Card                                  1.0     5.0     5.0
# $50 Physical Gift Card                                 1.0     5.0     NaN
# 1/10 Carat t.w. Diamond Promise Ring                   NaN     5.0     NaN
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             1.0     NaN     NaN
# Ống hút inox                                           NaN     5.0     NaN
# Ống hút kim loại                                       1.0     1.0     NaN
# Ống hút tre                                            NaN     NaN     NaN
# 레드슈즈                                                   NaN     1.0     NaN
#
# CustomerID                                          103991    103996  103997
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     NaN  4.000000     NaN
# $100 Physical Gift Card                                5.0  3.666667     NaN
# $25 Virtual Gift Card                                  NaN  4.500000     1.0
# $50 Physical Gift Card                                 NaN  3.600000     NaN
# 1/10 Carat t.w. Diamond Promise Ring                   NaN  3.500000     NaN
# ...                                                    ...       ...     ...
# Ống hút gạo OCHAO 500 Gram                             5.0  4.000000     NaN
# Ống hút inox                                           NaN  3.666667     1.0
# Ống hút kim loại                                       NaN  3.666667     NaN
# Ống hút tre                                            2.0  4.500000     NaN
# 레드슈즈                                                   NaN  5.000000     1.0
#
# [625 rows x 250 columns]

# %%
pt.fillna(0, inplace=True)
pt
# Out:
# CustomerID                                          6       13874   13879   \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     1.0     5.0     2.0
# $100 Physical Gift Card                                1.0     4.0     0.0
# $25 Virtual Gift Card                                  0.0     4.5     0.0
# $50 Physical Gift Card                                 1.0     5.0     0.0
# 1/10 Carat t.w. Diamond Promise Ring                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             1.0     0.0     2.0
# Ống hút inox                                           1.0     4.0     0.0
# Ống hút kim loại                                       0.0     5.0     5.0
# Ống hút tre                                            0.0     0.0     0.0
# 레드슈즈                                                   1.0     5.0     0.0
#
# CustomerID                                          14180   14902   14906   \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     0.0     1.0     0.0
# $100 Physical Gift Card                                0.0     1.0     4.0
# $25 Virtual Gift Card                                  0.0     0.0     4.0
# $50 Physical Gift Card                                 0.0     0.0     0.0
# 1/10 Carat t.w. Diamond Promise Ring                   0.0     1.0     0.0
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             4.0     0.0     0.0
# Ống hút inox                                           4.0     1.0     4.0
# Ống hút kim loại                                       0.0     1.0     0.0
# Ống hút tre                                            4.0     0.0     0.0
# 레드슈즈                                                   0.0     0.0     0.0
#
# CustomerID                                          15018   15042   15202   \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     0.0     2.0     0.0
# $100 Physical Gift Card                                4.0     0.0     0.0
# $25 Virtual Gift Card                                  0.0     0.0     0.0
# $50 Physical Gift Card                                 4.0     0.0     0.0
# 1/10 Carat t.w. Diamond Promise Ring                   4.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             4.0     5.0     0.0
# Ống hút inox                                           0.0     3.0     1.0
# Ống hút kim loại                                       0.0     3.5     1.0
# Ống hút tre                                            4.0     0.0     0.0
# 레드슈즈                                                   0.0     3.5     1.0
#
# CustomerID                                            22881   ...  103971  \
# Name                                                          ...
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...  0.000000  ...     0.0
# $100 Physical Gift Card                             5.000000  ...     5.0
# $25 Virtual Gift Card                               3.000000  ...     5.0
# $50 Physical Gift Card                              3.333333  ...     0.0
# 1/10 Carat t.w. Diamond Promise Ring                4.000000  ...     5.0
# ...                                                      ...  ...     ...
# Ống hút gạo OCHAO 500 Gram                          4.000000  ...     5.0
# Ống hút inox                                        3.200000  ...     0.0
# Ống hút kim loại                                    2.333333  ...     5.0
# Ống hút tre                                         4.000000  ...     5.0
# 레드슈즈                                                5.000000  ...     5.0
#
# CustomerID                                          103972  103977    103982  \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     5.0     0.0  0.000000
# $100 Physical Gift Card                                5.0     0.0  5.000000
# $25 Virtual Gift Card                                  0.0     0.0  5.000000
# $50 Physical Gift Card                                 5.0     0.0  0.000000
# 1/10 Carat t.w. Diamond Promise Ring                   5.0     0.0  5.000000
# ...                                                    ...     ...       ...
# Ống hút gạo OCHAO 500 Gram                             0.0     0.0  4.000000
# Ống hút inox                                           3.0     0.0  4.666667
# Ống hút kim loại                                       1.0     5.0  5.000000
# Ống hút tre                                            0.0     0.0  0.000000
# 레드슈즈                                                   0.0     5.0  5.000000
#
# CustomerID                                          103985  103987  103988  \
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     0.0     0.0     5.0
# $100 Physical Gift Card                                0.0     0.0     5.0
# $25 Virtual Gift Card                                  1.0     5.0     5.0
# $50 Physical Gift Card                                 1.0     5.0     0.0
# 1/10 Carat t.w. Diamond Promise Ring                   0.0     5.0     0.0
# ...                                                    ...     ...     ...
# Ống hút gạo OCHAO 500 Gram                             1.0     0.0     0.0
# Ống hút inox                                           0.0     5.0     0.0
# Ống hút kim loại                                       1.0     1.0     0.0
# Ống hút tre                                            0.0     0.0     0.0
# 레드슈즈                                                   0.0     1.0     0.0
#
# CustomerID                                          103991    103996  103997
# Name
# "Love" Necklace 14K Yellow Gold 16" to 18" Adju...     0.0  4.000000     0.0
# $100 Physical Gift Card                                5.0  3.666667     0.0
# $25 Virtual Gift Card                                  0.0  4.500000     1.0
# $50 Physical Gift Card                                 0.0  3.600000     0.0
# 1/10 Carat t.w. Diamond Promise Ring                   0.0  3.500000     0.0
# ...                                                    ...       ...     ...
# Ống hút gạo OCHAO 500 Gram                             5.0  4.000000     0.0
# Ống hút inox                                           0.0  3.666667     1.0
# Ống hút kim loại                                       0.0  3.666667     0.0
# Ống hút tre                                            2.0  4.500000     0.0
# 레드슈즈                                                   0.0  5.000000     1.0
#
# [625 rows x 250 columns]

# %%
#distance calculation
#each products becomes vector and we will calculate the eulicaten distance

from sklearn.metrics.pairwise import cosine_similarity

# %%
#distance (similarity score)
sim_score = cosine_similarity(pt)
sim_score
# Out:
# array([[1.        , 0.61348343, 0.53541558, ..., 0.55868415, 0.51042143,
#         0.5056698 ],
#        [0.61348343, 1.        , 0.60133637, ..., 0.58886603, 0.62694099,
#         0.56969447],
#        [0.53541558, 0.60133637, 1.        , ..., 0.56109151, 0.56038688,
#         0.51936784],
#        ...,
#        [0.55868415, 0.58886603, 0.56109151, ..., 1.        , 0.54018535,
#         0.58313626],
#        [0.51042143, 0.62694099, 0.56038688, ..., 0.54018535, 1.        ,
#         0.60190701],
#        [0.5056698 , 0.56969447, 0.51936784, ..., 0.58313626, 0.60190701,
#         1.        ]])

# %%
def recProduct(name):
    #index fetch of the particular products
    index = np.where(pt.index == name)[0][0]
    #removed the 0th products which same book, so from 1 to 6 total 5 products
    similar_products = sorted(list(enumerate(sim_score[index])), key=lambda x:x[1], reverse=True)[1:6] #sorted based on similarity score

    print('Recommned products you may like: ')
    for i in similar_products:
        print(pt.index[i[0]]) #index print

# %%
recProduct(input('Enter your product name: '))
# Out:
# Enter your product name: $100 Physical Gift Card
# Recommned products you may like:
# Diamond Promise Ring 1/6 ct tw Round-cut 10K White Gold
# Forever Connected Diamond Necklace 1 ct tw Round/Pear 10K White Gold 18"
# Forever Connected Diamond Necklace 1/2 ct tw Round/Pear 10K White Gold 18"
# Forever Connected Diamond Necklace 1/3 ct tw Round/Princess 10K Yellow Gold 18"
# Lab-Created Opal & White Lab-Created Sapphire 'Mom' Heart Necklace Sterling Silver 18"
